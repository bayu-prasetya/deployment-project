# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('test_2025.csv')
sample = df.sample(1, random_state=42)

# %%
sample_dict = sample.to_dict(orient='records')
sample_dict
# Out:
# [{'claim_number': 4422,
#   'age_of_driver': 37,
#   'gender': 'M',
#   'marital_status': 1.0,
#   'safty_rating': 83,
#   'annual_income': 116012,
#   'high_education_ind': 1,
#   'address_change_ind': 0,
#   'living_status': 'Own',
#   'zip_code': 80004,
#   'claim_date': '8/30/2016',
#   'claim_day_of_week': 'Tuesday',
#   'accident_site': 'Local',
#   'past_num_of_claims': 0,
#   'witness_present_ind': 0.0,
#   'liab_prct': 100,
#   'channel': 'Broker',
#   'policy_report_filed_ind': 1,
#   'claim_est_payout': 4985.68,
#   'age_of_vehicle': 4,
#   'vehicle_category': 'Large',
#   'vehicle_price': 54836.204168910524,
#   'vehicle_color': 'blue',
#   'vehicle_weight': 7849.137798999999}]

# %%
pd.DataFrame(sample_dict).columns
# Out:
# Index(['claim_number', 'age_of_driver', 'gender', 'marital_status',
#        'safty_rating', 'annual_income', 'high_education_ind',
#        'address_change_ind', 'living_status', 'zip_code', 'claim_date',
#        'claim_day_of_week', 'accident_site', 'past_num_of_claims',
#        'witness_present_ind', 'liab_prct', 'channel',
#        'policy_report_filed_ind', 'claim_est_payout', 'age_of_vehicle',
#        'vehicle_category', 'vehicle_price', 'vehicle_color', 'vehicle_weight'],
#       dtype='object')

# %%
response = requests.post('https://deployment-project-production-c35e.up.railway.app/predict', json=sample_dict)

# %%
x = response.json()
x
# Out:
# {'detail': "Invalid schema. Expected ['claim_number', 'age_of_driver', 'gender', 'marital_status', 'safty_rating', 'annual_income', 'high_education_ind', 'address_change_ind', 'living_status', 'zip_code', 'claim_date', 'claim_day_of_week', 'accident_site', 'past_num_of_claims', 'witness_present_ind', 'liab_prct', 'channel', 'policy_report_filed_ind', 'claim_est_payout', 'age_of_vehicle', 'vehicle_category', 'vehicle_price', 'vehicle_color', 'vehicle_weight']"}
